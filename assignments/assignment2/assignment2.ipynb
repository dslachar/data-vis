# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Part 1

# %%
# Create a list of the atomic weights of the first six elements of the periodic table, 
# each rounded to the nearest integer. 

atomic_weights = [1, 4, 7, 9, 11, 12]

# %%
# Provide two pie charts as follows: 
# (1) each slice annotated with a percentage of the whole
# (2) each slice annotated with its atomic weight
# Explode a different element with each chart
explode1 = (1,0,0,0,0,0)
explode2 = (0,0,0,0,1,0)
labels = 'Hydrogen','Helium','Lithium','Beryllium','Boron','Carbon'
fig,axs = plt.subplots(1,2)

axs[0].pie(atomic_weights, explode = explode1, labels=labels, 
           autopct='%1.1f%%',radius=100, 
           startangle=180)
axs[1].pie(atomic_weights, explode = explode2, labels=labels, 
           autopct=lambda p: '{:.0f}'.format(p * sum(atomic_weights) / 100),radius=100,
           startangle=180)

axs[0].axis('equal')
axs[1].axis('equal')
axs[0].title.set_text('First Six Elements With Percentage of All')
axs[1].title.set_text('First Six Elements With Atomic Weight')
plt.tight_layout(pad=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-c7cffd8b24e4> in <module>
#      19 axs[0].title.set_text('First Six Elements With Percentage of All')
#      20 axs[1].title.set_text('First Six Elements With Atomic Weight')
# ---> 21 plt.tight_layout(pad=50)
#      22 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1364     """
#    1365     fig = gcf()
# -> 1366     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1367
#    1368
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2274             self, self.axes, subplotspec_list, renderer,
#    2275             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
# -> 2276         self.subplots_adjust(**kwargs)
#    2277
#    2278     def align_xlabels(self, axs=None):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in subplots_adjust(self, *args, **kwargs)
#    2086
#    2087         """
# -> 2088         self.subplotpars.update(*args, **kwargs)
#    2089         for ax in self.axes:
#    2090             if not isinstance(ax, SubplotBase):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in update(self, left, bottom, right, top, wspace, hspace)
#     239             if self.left >= self.right:
#     240                 reset()
# --> 241                 raise ValueError('left cannot be >= right')
#     242
#     243             if self.bottom >= self.top:
#
# ValueError: left cannot be >= right

# %%
# 
# Explode a different element with each chart
