# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Part 1

# %%
# Create a list of the atomic weights of the first six elements of the periodic table, 
# each rounded to the nearest integer. 

atomic_weights = [1, 4, 7, 9, 11, 12]

# %%
# Provide two pie charts as follows: 
# (1) each slice annotated with a percentage of the whole
# (2) each slice annotated with its atomic weight
# Explode a different element with each chart
explode1 = (1,0,0,0,0,0)
explode2 = (0,0,0,0,1,0)
labels = 'Hydrogen','Helium','Lithium','Beryllium','Boron','Carbon'
fig,axs = plt.subplots(1,2)

axs[0].pie(atomic_weights, explode = explode1, labels=labels, 
           autopct='%1.1f%%',radius=100, 
           startangle=180)
axs[1].pie(atomic_weights, explode = explode2, labels=labels, 
           autopct=lambda p: '{:.0f}'.format(p * sum(atomic_weights) / 100),radius=100,
           startangle=180)

axs[0].axis('equal')
axs[1].axis('equal')
axs[0].title.set_text('First Six Elements With Percentage of All')
axs[1].title.set_text('First Six Elements With Atomic Weight')
#plt.tight_layout(pad=50)
plt.show()

# %% [markdown]
# # Part 2

# %%
# Read into a DataFrame the file py_ide2.csv and a vertical bar chart.

# %%
df_py_ide = pd.read_csv('py_ide2.csv')
df_py_ide
# Out:
#              IDE  Adoption
# 0        Jupyter      57.0
# 1        PyCharm      35.0
# 2         Spyder      27.0
# 3        VS Code      21.0
# 4   Sublime Text      12.0
# 5           Atom      10.0
# 6            Vim       8.5
# 7    another IDE       3.1
# 8        Eclipse       3.0
# 9     another ed       2.5
# 10         Emacs       2.2
# 11         gedit       1.3
# 12         Rodeo       1.2

# %%
# provide a horizontal bar chart, complete with all labels
# a vertical bar chart, , complete with all labels

# %%
fig2, axs2 = plt.subplots(1,2)

height = df_py_ide['Adoption']
bars = df_py_ide['IDE']
axs2[0].barh(bars,height)
axs2[1].bar(bars,height)
plt.xticks(rotation='vertical')
plt.show()
